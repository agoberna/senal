# %%
import pandas as pd

# %%
# !pip install fast_ml
# Out:
# ...
#   Using cached fast_ml-3.68-py3-none-any.whl (42 kB)
# ...
# WARNING: You are using pip version 21.0.1; however, version 22.0.4 is available.
# You should consider upgrading via the '/Users/alexgoberna/.virtualenvs/cv/bin/python -m pip install --upgrade pip' command.

# %%
from fast_ml.model_development import train_valid_test_split

# %%
df = pd.read_csv('/content/TextCSV.csv', encoding="ISO-8859-1", low_memory=False)

# %%
X_train, y_train, X_valid, y_valid, X_test, y_test = train_valid_test_split(df, target = 'Label', 
                                                                            train_size=0.8, valid_size=0.1, test_size=0.1)

# %%
print(X_train.shape), print(y_train.shape)
print(X_valid.shape), print(y_valid.shape)
print(X_test.shape), print(y_test.shape)
# Out:
# (2427, 1)
# (2427,)
# (303, 1)
# (303,)
# (304, 1)
# (304,)
# (None, None)

# %%
X_train.head
# Out:
# <bound method NDFrame.head of                                                    Text
# 690   Recientamente fui al Guatemala para hacer inve...
# 1205  El verano pasado, durantes las vacaciones, viv...
# 1844  Quiero hablar de la región donde vivo en Franc...
# 2586  Primero, cuando Chaplin andadó en afuera cayó ...
# 1973  El año pasado pasé las vacaciones de verano en...
# ...                                                 ...
# 2746  Un día un niño llevó una rana a su casa. En la...
# 2151  Es un video con Charlie Chaplin. El esta camin...
# 1317  Un día habia una muchacho se llama Pedro y su ...
# 314   Yo soy Andrel Simmons. Soy de Valdosta, Georgi...
# 1954  Este verano pasé el mes de julio en Perú. Fui ...
#
# [2427 rows x 1 columns]>

# %%
y_train
# Out:
# 690     Lower_intermediate
# 1205    Upper_intermediate
# 1844        Upper_advanced
# 2586        Upper_beginner
# 1973        Upper_advanced
#                ...
# 2746        Lower_advanced
# 2151    Lower_intermediate
# 1317    Upper_intermediate
# 314         Upper_beginner
# 1954        Upper_advanced
# Name: Label, Length: 2427, dtype: object

# %%
X_valid.head
# Out:
# <bound method NDFrame.head of                                                    Text
# 1038  Para mis vacaciónes en el año pasado, fui a Or...
# 1761  La región donde vivo, el oeste de Escocia, pre...
# 331   Me fui a la cama anoche. Dije buenas noches a ...
# 2080  Al principio del video ves al hombre caminando...
# 2060  El personaje (Charles Chaplin) encuentra un be...
# ...                                                 ...
# 1114  Aprendi Espanol quando estaba in escuela secon...
# 118   Hola, me llamo Jake. Yo vivo en Lafayette, Ind...
# 2657  Chaplin busca un bebé por casualidad, y está p...
# 620   Yo voy a escribir sobre una persona famosa. Su...
# 2140  Este video trata de la película de Charlie Cha...
#
# [303 rows x 1 columns]>

# %%
X_test.head
# Out:
# <bound method NDFrame.head of                                                    Text
# 1764  Últimamente, dado el tiempo fatal en Andalucía...
# 1375  Pienso que la nueva ley anti-tabaco viola la c...
# 2567  Se llamo Chaplin.Es pequeño y gordo. Se puso u...
# 2776  Al principio del video Chaplin estava en una c...
# 696   Vivo en York con mi marido Neil y mi hija Frey...
# ...                                                 ...
# 1448  hhh hay una hay un hombre que está hhh andando...
# 1211  Yo vivo en la region de Dallas, TX en los Esta...
# 1380  Mis vacaciones del ano pasado estaban MUY inte...
# 149   UNA PELÍCULA SOBRE UN BEBÉ ENCONTRADO Y BUSCAN...
# 1268  ¿Qué opinas de la nueva ley anti-tobaco? A mi ...
#
# [304 rows x 1 columns]>

# %% [markdown]
# # Merging the train data

# %%
train = pd.merge(X_train, y_train, left_index=True, right_index=True)

# %%
train
# Out:
#                                                    Text               Label
# 690   Recientamente fui al Guatemala para hacer inve...  Lower_intermediate
# 1205  El verano pasado, durantes las vacaciones, viv...  Upper_intermediate
# 1844  Quiero hablar de la región donde vivo en Franc...      Upper_advanced
# 2586  Primero, cuando Chaplin andadó en afuera cayó ...      Upper_beginner
# 1973  El año pasado pasé las vacaciones de verano en...      Upper_advanced
# ...                                                 ...                 ...
# 2746  Un día un niño llevó una rana a su casa. En la...      Lower_advanced
# 2151  Es un video con Charlie Chaplin. El esta camin...  Lower_intermediate
# 1317  Un día habia una muchacho se llama Pedro y su ...  Upper_intermediate
# 314   Yo soy Andrel Simmons. Soy de Valdosta, Georgi...      Upper_beginner
# 1954  Este verano pasé el mes de julio en Perú. Fui ...      Upper_advanced
#
# [2427 rows x 2 columns]

# %%
train.reset_index(drop=True, inplace=True)

# %%
train
# Out:
#                                                    Text               Label
# 0     Recientamente fui al Guatemala para hacer inve...  Lower_intermediate
# 1     El verano pasado, durantes las vacaciones, viv...  Upper_intermediate
# 2     Quiero hablar de la región donde vivo en Franc...      Upper_advanced
# 3     Primero, cuando Chaplin andadó en afuera cayó ...      Upper_beginner
# 4     El año pasado pasé las vacaciones de verano en...      Upper_advanced
# ...                                                 ...                 ...
# 2422  Un día un niño llevó una rana a su casa. En la...      Lower_advanced
# 2423  Es un video con Charlie Chaplin. El esta camin...  Lower_intermediate
# 2424  Un día habia una muchacho se llama Pedro y su ...  Upper_intermediate
# 2425  Yo soy Andrel Simmons. Soy de Valdosta, Georgi...      Upper_beginner
# 2426  Este verano pasé el mes de julio en Perú. Fui ...      Upper_advanced
#
# [2427 rows x 2 columns]

# %%
train.to_csv("train.tsv", sep="\t",  index = False)

# %% [markdown]
# # Merging the dev data

# %%
dev = pd.merge(X_valid, y_valid, left_index=True, right_index=True)

# %%
dev
# Out:
#                                                    Text               Label
# 1038  Para mis vacaciónes en el año pasado, fui a Or...  Upper_intermediate
# 1761  La región donde vivo, el oeste de Escocia, pre...      Lower_advanced
# 331   Me fui a la cama anoche. Dije buenas noches a ...      Upper_beginner
# 2080  Al principio del video ves al hombre caminando...      Upper_advanced
# 2060  El personaje (Charles Chaplin) encuentra un be...      Lower_advanced
# ...                                                 ...                 ...
# 1114  Aprendi Espanol quando estaba in escuela secon...  Upper_intermediate
# 118   Hola, me llamo Jake. Yo vivo en Lafayette, Ind...      Lower_beginner
# 2657  Chaplin busca un bebé por casualidad, y está p...  Lower_intermediate
# 620   Yo voy a escribir sobre una persona famosa. Su...  Lower_intermediate
# 2140  Este video trata de la película de Charlie Cha...      Lower_advanced
#
# [303 rows x 2 columns]

# %%
dev.reset_index(drop=True, inplace=True)

# %%
dev
# Out:
#                                                   Text               Label
# 0    Para mis vacaciónes en el año pasado, fui a Or...  Upper_intermediate
# 1    La región donde vivo, el oeste de Escocia, pre...      Lower_advanced
# 2    Me fui a la cama anoche. Dije buenas noches a ...      Upper_beginner
# 3    Al principio del video ves al hombre caminando...      Upper_advanced
# 4    El personaje (Charles Chaplin) encuentra un be...      Lower_advanced
# ..                                                 ...                 ...
# 298  Aprendi Espanol quando estaba in escuela secon...  Upper_intermediate
# 299  Hola, me llamo Jake. Yo vivo en Lafayette, Ind...      Lower_beginner
# 300  Chaplin busca un bebé por casualidad, y está p...  Lower_intermediate
# 301  Yo voy a escribir sobre una persona famosa. Su...  Lower_intermediate
# 302  Este video trata de la película de Charlie Cha...      Lower_advanced
#
# [303 rows x 2 columns]

# %%
dev.to_csv("dev.tsv", sep="\t",  index = False)

# %% [markdown]
# # Merging the test data

# %%
test = pd.merge(X_test, y_test, left_index=True, right_index=True)

# %%
test
# Out:
#                                                    Text               Label
# 1764  Últimamente, dado el tiempo fatal en Andalucía...      Lower_advanced
# 1375  Pienso que la nueva ley anti-tabaco viola la c...      Lower_advanced
# 2567  Se llamo Chaplin.Es pequeño y gordo. Se puso u...      Upper_beginner
# 2776  Al principio del video Chaplin estava en una c...      Upper_beginner
# 696   Vivo en York con mi marido Neil y mi hija Frey...  Lower_intermediate
# ...                                                 ...                 ...
# 1448  hhh hay una hay un hombre que está hhh andando...      Lower_advanced
# 1211  Yo vivo en la region de Dallas, TX en los Esta...  Upper_intermediate
# 1380  Mis vacaciones del ano pasado estaban MUY inte...      Lower_advanced
# 149   UNA PELÍCULA SOBRE UN BEBÉ ENCONTRADO Y BUSCAN...      Lower_beginner
# 1268  ¿Qué opinas de la nueva ley anti-tobaco? A mi ...  Upper_intermediate
#
# [304 rows x 2 columns]

# %%
test.reset_index(drop=True, inplace=True)

# %%
test.to_csv("test.tsv", sep="\t",  index = False)

# %% [markdown]
# #Multilabel classification in Spanish Bert
# Taken from: https://www.philschmid.de/bert-text-classification-in-a-different-language

# %%
# !pip install simpletransformers
# Out:
# ...
#   Using cached simpletransformers-0.63.6-py3-none-any.whl (249 kB)
# ...
#   Using cached streamlit-1.8.1-py2.py3-none-any.whl (10.1 MB)
# ...
#   Using cached tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
# ...
#   Using cached datasets-2.0.0-py3-none-any.whl (325 kB)
# ...
#   Using cached sentencepiece-0.1.96-cp38-cp38-macosx_10_6_x86_64.whl (1.1 MB)
# ...
#   Using cached seqeval-1.2.2-py3-none-any.whl
# ...
# WARNING: You are using pip version 21.0.1; however, version 22.0.4 is available.
# You should consider upgrading via the '/Users/alexgoberna/.virtualenvs/cv/bin/python -m pip install --upgrade pip' command.

# %%
# !pip freeze | grep simpletransformers
# Out:
# simpletransformers==0.63.6

# %%
from sklearn.model_selection import train_test_split
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/alexgoberna/Desktop/senal/MLClassifier/Model/TrainDevTestSplit&Train.ipynb Cell 31' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/alexgoberna/Desktop/senal/MLClassifier/Model/TrainDevTestSplit%26Train.ipynb#ch0000030?line=0'>1</a> from sklearn.model_selection import train_test_split
#
# File ~/.virtualenvs/cv/lib/python3.8/site-packages/sklearn/__init__.py:82, in <module>
#      <a href='file:///~/.virtualenvs/cv/lib/python3.8/site-packages/sklearn/__init__.py?line=79'>80</a> from . import _distributor_init  # noqa: F401
#      <a href='file:///~/.virtualenvs/cv/lib/python3.8/site-packages/sklearn/__init__.py?line=80'>81</a> from . import __check_build  # noqa: F401
# ---> <a href='file:///~/.virtualenvs/cv/lib/python3.8/site-packages/sklearn/__init__.py?line=81'>82</a> from .base import clone
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('TextCSV.csv', encoding='Latin-1')

# %%
train_df, test_df = train_test_split(df, test_size=0.10)

# %%
print('train shape: ',train_df.shape)
print('test shape: ',test_df.shape)
# Out:
# train shape:  (2730, 2)
# test shape:  (304, 2)

# %%
pip install torch
# Out:
# ...
#      |████████████████████████████████| 129.9 MB 33 kB/s s eta 0:00:01    |███████████▎                    | 45.6 MB 8.9 MB/s eta 0:00:10     |█████████████                   | 52.4 MB 8.9 MB/s eta 0:00:09     |███████████████▌                | 63.0 MB 10.2 MB/s eta 0:00:07     |█████████████████████▉          | 88.6 MB 4.5 MB/s eta 0:00:10     |██████████████████████████      | 105.7 MB 6.1 MB/s eta 0:00:04     |███████████████████████████▏    | 110.4 MB 3.8 MB/s eta 0:00:06     |█████████████████████████████▋  | 120.3 MB 6.7 MB/s eta 0:00:02     |██████████████████████████████▊ | 124.7 MB 13.6 MB/s eta 0:00:01     |███████████████████████████████▏| 126.4 MB 13.6 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.0.1; however, version 22.0.4 is available.
# You should consider upgrading via the '/Users/alexgoberna/.virtualenvs/cv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Load Pretrained Model

# %%
from simpletransformers.classification import ClassificationModel

# define hyperparameter
train_args ={"reprocess_input_data": True,
             "fp16":False,
             "num_train_epochs": 10, 
             'overwrite_output_dir': True,
             'train_batch_size':  32,
             'max_seq_length': 128}

# %%
# Create a ClassificationModel
# Model taken from: https://huggingface.co/mrm8488/distill-bert-base-spanish-wwm-cased-finetuned-spa-squad2-es
model = ClassificationModel("bert", "mrm8488/distill-bert-base-spanish-wwm-cased-finetuned-spa-squad2-es", num_labels=6, args=train_args)
# Out:
# Downloading:   0%|          | 0.00/465 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/419M [00:00<?, ?B/s]
# Some weights of the model checkpoint at mrm8488/distill-bert-base-spanish-wwm-cased-finetuned-spa-squad2-es were not used when initializing BertForSequenceClassification: ['qa_outputs.weight', 'qa_outputs.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
model.train_model(train_df)
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:586: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/2730 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use thePyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ...
# Running Epoch 9 of 10:   0%|          | 0/86 [00:00<?, ?it/s]
# (860, 0.4942235124676467)

# %%
from sklearn.metrics import f1_score, accuracy_score

def f1_multiclass(labels, preds):
  return f1_score(labels, preds, average='micro')

result, model_outputs, wrong_predictions = model.eval_model(test_df, f1=f1_multiclass, acc=accuracy_score)
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1427: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# ...
# Running Evaluation:   0%|          | 0/38 [00:00<?, ?it/s]

# %%
print(result)
# Out:
# {'mcc': 0.39979176848226416, 'f1': 0.5328947368421053, 'acc': 0.5328947368421053, 'eval_loss': 2.2699905147677972}

# %% [markdown]
# # Save the trained model

# %%
import os
import tarfile

def pack_model(model_path='',file_name=''):
  files = [files for root, dirs, files in os.walk(model_path)][0]
  with tarfile.open(file_name+ '.tar.gz', 'w:gz') as f:
    for file in files:
      f.add(f'{model_path}/{file}')

# %%
# run the function
pack_model('/content/outputs','L2SpanishWriting')

# %% [markdown]
# # Unpack the model and predict a real example

# %%
import os
import tarfile

def unpack_model(model_name=''):
  tar = tarfile.open(f"{model_name}.tar.gz", "r:gz")
  tar.extractall()
  tar.close()

unpack_model('L2SpanishWriting')

# %% [markdown]
# # specifying the correct arguments for loading the model

# %%
from simpletransformers.classification import ClassificationModel

# define hyperparameter
train_args ={"reprocess_input_data": True,
             "fp16":False,
             "num_train_epochs": 10, 
             'overwrite_output_dir': True,
             'train_batch_size':  32,
             'max_seq_length': 128}

# Create a ClassificationModel with our trained model
model = ClassificationModel("bert", 'content/outputs', num_labels=6, args=train_args, use_cuda=False)

# %% [markdown]
# # Using the model
# #### Multilabel Classification Schema
# Lower_Beginner = 0
#
# Upper_Beginner = 1
#
# Lower_Intermediate = 2
#
# Upper_Intermediate = 3
#
# Lower_Advanced = 4
#
# Upper_Advanced = 5

# %%
class_list = ['Lower_Beginner','Upper_Beginner','Lower_Intermediate','Upper_Intermediate', 'Lower_Advanced', 'Upper_Advanced']

test_comp1 = "El spanglish es una phenomena cultural de una mezcla de los dos diferentes idiomas y culturas. Personas suficiente hablan en spanglish para lo ser considerado una subsección de dos ingles y español."

predictions, raw_outputs = model.predict([test_comp1])

print(class_list[predictions[0]])

test_comp2 = "Les escribo en repuesta a su aviso de búsqueda de un empleado para ser asistente editorial. He conocido su programa desde mi primer año en la universidad, cuando lo usé en mi clase de español. Continuo utilizar VHL hoy en día. Siempre recomiendo los libros de VHL a cualquier persona que quiere aprender otro idioma."

predictions, raw_outputs = model.predict([test_comp2])

print(class_list[predictions[0]])
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ...
# 100%|██████████| 1/1 [00:00<00:00,  1.13it/s]
# Lower_Intermediate
#   0%|          | 0/1 [00:00<?, ?it/s]
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ...
# 100%|██████████| 1/1 [00:00<00:00,  1.34it/s]
# Upper_Intermediate

# %% [markdown]
# ## Trying the multilingual BERT

# %%
from simpletransformers.classification import ClassificationModel

# define hyperparameter
train_args ={"reprocess_input_data": True,
             "fp16":False,
             "num_train_epochs": 7, 
             'overwrite_output_dir': True,
             'train_batch_size':  13,
             'max_seq_length': 256}

# %%
# Create a ClassificationModel
# Model taken from: https://huggingface.co/dccuchile/bert-base-spanish-wwm-cased
model = ClassificationModel("bert", "dccuchile/bert-base-spanish-wwm-cased", num_labels=6, args=train_args)
# Out:
# Downloading:   0%|          | 0.00/648 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/419M [00:00<?, ?B/s]
# Some weights of the model checkpoint at dccuchile/bert-base-spanish-wwm-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.decoder.weight', 'cls.predictions.decoder.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %%
model.train_model(train_df)
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:586: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/2730 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use thePyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ...
# Running Epoch 6 of 7:   0%|          | 0/210 [00:00<?, ?it/s]
# (1470, 0.5530159330876151)

# %%
from sklearn.metrics import f1_score, accuracy_score

def f1_multiclass(labels, preds):
  return f1_score(labels, preds, average='micro')

result, model_outputs, wrong_predictions = model.eval_model(test_df, f1=f1_multiclass, acc=accuracy_score)
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1427: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# ...
# Running Evaluation:   0%|          | 0/38 [00:00<?, ?it/s]

# %%
print(result)
# Out:
# {'mcc': 0.3686126248853768, 'f1': 0.4967105263157895, 'acc': 0.4967105263157895, 'eval_loss': 2.5704626284147563}
